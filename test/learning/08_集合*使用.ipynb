# %%
list1 = [1, 2, 5, 3]
a, b, *_ = list1
print(_)

list2 = [1, 2, 5, 3]
list2.pop()
print(list2)
list2.insert(-1,99)
print(list2)
list2.reverse()
print(list2)
list2.index(99)
list2.count(2)
list2.sort()
list3=list2+list1
list3
# Out:
# [5, 3]
# [1, 2, 5]
# [1, 2, 99, 5]
# [5, 99, 2, 1]
# [1, 2, 5, 99, 1, 2, 5, 3]

# %%
dict1={"a":"valuea","b":"valueb"}
dict2 = {"c": "valuea", "d": "valueb"}
dict1.popitem()
dict2.pop("c")
dict2.clear()
dict1
dict1.get("a")

# dict1.update(dict2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /root/project/python/test/learning/集合*使用.ipynb Cell 2' in <cell line: 8>()
#       <a href='vscode-notebook-cell://code.19931006.xyz:8443/root/project/python/test/learning/%E9%9B%86%E5%90%88%2A%E4%BD%BF%E7%94%A8.ipynb#ch0000007vscode-remote?line=5'>6</a> dict1
#       <a href='vscode-notebook-cell://code.19931006.xyz:8443/root/project/python/test/learning/%E9%9B%86%E5%90%88%2A%E4%BD%BF%E7%94%A8.ipynb#ch0000007vscode-remote?line=6'>7</a> dict1.get("a")
# ----> <a href='vscode-notebook-cell://code.19931006.xyz:8443/root/project/python/test/learning/%E9%9B%86%E5%90%88%2A%E4%BD%BF%E7%94%A8.ipynb#ch0000007vscode-remote?line=7'>8</a> dict1+dict2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
set1={'1','2','3'}
set2 = {'4', '2', '3'}
# set1[0]=2
# print(type(set1))
set1.add("a")
print(set1)
set1.update(set2)
print(set1)
set1.pop()
print(set1)
# set1.remove("2")
# set1.is
'2' in set1
print(set1-set2)
print(set1|set2)
print(set1&set2)
print("^",set1^set2)
set3 = {'a', '2', '4', '1', '3'}
set3
# Out:
# {'3', '1', '2', 'a'}
# {'a', '3', '1', '2', '4'}
# {'3', '1', '2', '4'}
# {'1'}
# {'3', '1', '2', '4'}
# {'4', '2', '3'}
# ^ {'1'}
# {'1', '2', '3', '4', 'a'}

# %%
test1='wa ha ha  1   '
test1.strip()
test2=test1.split(" ",maxsplit=3)
print(test1)
print(test2)
test1.index('h')
test1.upper()
test1.replace("a","b")
print(test1)
test1.startswith("w")
test1.endswith(" ")
test1.isalnum()
test1.isalpha()
test1.find("d")
test1.index("d")
# Out:
# wa ha ha  1
# ['wa', 'ha', 'ha', ' 1   ']
# wa ha ha  1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /root/project/python/test/learning/集合*使用.ipynb Cell 4' in <cell line: 15>()
#      <a href='vscode-notebook-cell://code.19931006.xyz:8443/root/project/python/test/learning/%E9%9B%86%E5%90%88%2A%E4%BD%BF%E7%94%A8.ipynb#ch0000010vscode-remote?line=12'>13</a> test1.isalpha()
#      <a href='vscode-notebook-cell://code.19931006.xyz:8443/root/project/python/test/learning/%E9%9B%86%E5%90%88%2A%E4%BD%BF%E7%94%A8.ipynb#ch0000010vscode-remote?line=13'>14</a> test1.find("d")
# ---> <a href='vscode-notebook-cell://code.19931006.xyz:8443/root/project/python/test/learning/%E9%9B%86%E5%90%88%2A%E4%BD%BF%E7%94%A8.ipynb#ch0000010vscode-remote?line=14'>15</a> test1.index("d")
#
# ValueError: substring not found

# %%
tuple1=(1,2,3)
tuple2=(2,3,4)
tuple1=tuple1-tuple2
tuple2.
print(tuple1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /root/project/python/test/learning/集合*使用.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell://code.19931006.xyz:8443/root/project/python/test/learning/%E9%9B%86%E5%90%88%2A%E4%BD%BF%E7%94%A8.ipynb#ch0000004vscode-remote?line=0'>1</a> tuple1=(1,2,3)
#       <a href='vscode-notebook-cell://code.19931006.xyz:8443/root/project/python/test/learning/%E9%9B%86%E5%90%88%2A%E4%BD%BF%E7%94%A8.ipynb#ch0000004vscode-remote?line=1'>2</a> tuple2=(2,3,4)
# ----> <a href='vscode-notebook-cell://code.19931006.xyz:8443/root/project/python/test/learning/%E9%9B%86%E5%90%88%2A%E4%BD%BF%E7%94%A8.ipynb#ch0000004vscode-remote?line=2'>3</a> tuple1=tuple1-tuple2
# ...
