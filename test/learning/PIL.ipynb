# %%
# !pip install pillow
# Out:
# Looking in indexes: https://repo.huaweicloud.com/repository/pypi/simple
# ...
#      |████████████████████████████████| 3.3 MB 39.6 MB/s eta 0:00:01     |███████▎                        | 747 kB 39.6 MB/s eta 0:00:01
# ...

# %%
from PIL import Image

img1 = Image.open('pil_test.png')
img1.show()

Image.eval(img1, lambda x: x*2).show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1080x830>
# <PIL.Image.Image image mode=RGBA size=1080x830>

# %%
img2=img1.copy()

img2.thumbnail((200,200))
img2.show()
img2.size
img2.save("./img2.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=200x154>
